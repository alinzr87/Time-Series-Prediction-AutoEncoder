# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error as mse
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential,Model
from keras.layers import Input,LSTM, Dense, Flatten, Conv1D, Lambda, Reshape
from keras.layers.merge import concatenate, multiply,add
import tensorflow as tf
from keras import regularizers
from keras.initializers import glorot_uniform
from tqdm import tqdm
from keras import regularizers
from keras.models import load_model
from statsmodels.tsa.seasonal import seasonal_decompose
import datetime
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler


import rpy2
import rpy2.robjects.numpy2ri
from stldecompose import decompose
rpy2.robjects.numpy2ri.activate()
from rpy2.robjects.packages import importr
from rpy2.robjects import r, pandas2ri
pandas2ri.activate()
stats = importr('stats')
stl=stats.stl
ts =stats.ts
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data= pd.read_csv("Data/FromMohammed/cif_dataset_complete.csv",header=None)
predictions = pd.read_csv("Data/FromMohammed/theta_25_horg.csv",index_col=0,skiprows = [1])
print(data.shape)
print(predictions.shape)
# Out:
# (72, 123)
# (72, 90)

# %%
def make_input(data,window_size,horizon=1):
    length=data.shape[0]
#     depth=data.shape[2]
    y = np.zeros([length-window_size+1-horizon,horizon])
    output=np.zeros([length-window_size+1-horizon,window_size])
    for i in range(length-window_size+1-horizon):
        output[i:i+1,:]=data[i:i+window_size]
        y[i,:]= data[i+window_size:i+window_size+horizon]
    return output.reshape(output.shape[0],window_size,1), y
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
def make_k_input(data,window_size,horizon):
    length = data.shape[0]
    output= np.zeros([length-window_size+1-horizon,horizon])
    for i in range(length-window_size-horizon+1):
        output[i:i+1,:]=data[i+window_size:i+window_size+horizon]
    return output.reshape(output.shape[0],horizon,1)
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
def nonov_make_input(data,window_size,horizon=1):
    length=data.shape[0]-window_size
    loop=length//horizon
    extra = length%horizon
#     print(str(extra))
    data = np.append(data,np.zeros([horizon-extra]))
#     print(data)
    if extra ==0:
        i_val = loop
    else:
        i_val=loop+1
        
    output=np.zeros([i_val,window_size])
    y=np.zeros([i_val,horizon])
    for i in range(i_val):
        output[i:i+1,:]=data[i*horizon:(i*horizon)+window_size]
        y[i,:]= data[(i*horizon)+window_size:(i*horizon)+window_size+horizon]
        
    return output.reshape(output.shape[0],window_size,1), y
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
def nonov_make_k_input(data,window_size,horizon):
    length = data.shape[0]-window_size
    loop=length//horizon
    extra = length%horizon
    data_app = np.repeat(data[-1],extra)
    data = np.append(data,data_app)    
#     data = np.append(data,np.zeros([horizon-extra]))
    if extra ==0:
        i_val = loop
    else:
        i_val=loop+1
    output=np.zeros([i_val,horizon])
    for i in range(i_val):
        output[i:i+1,:]=data[(i*horizon)+window_size:(i*horizon)+window_size+horizon]
    return output.reshape(output.shape[0],horizon,1)

# %%
def smape(val,preds,horizon):
    temp = np.abs(val-preds)
    temp1=np.abs(val)+np.abs(preds)
    
    smape = 200/horizon*np.sum(temp/temp1)

    return smape




def smape_nzr(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200.0 * np.mean(diff)

# %% [markdown]
# # Auto-Encoder

# %% [markdown]
# ### Horizon =6        (6--->4)

# %%
theta_length = predictions.shape[0]

horizon=6
window_size=6
theta_all=np.zeros(0)
for i in range(theta_length):
    current_pred= np.asarray(predictions.iloc[i].dropna().values,dtype=float)
    theta_all=np.concatenate((theta_all,current_pred),axis=0)
theta_input = make_k_input(theta_all,window_size,horizon)
normalized_theta_input=np.zeros(theta_input.shape)
for j in range(theta_input.shape[0]):
    scaler = MinMaxScaler()
    scaler.fit(theta_input[j])
    normalized_theta_input[j]= scaler.transform(theta_input[j])
#######################################################################################
norm_reshaped_input=normalized_theta_input.reshape(normalized_theta_input.shape[0],6)
ncol = normalized_theta_input.shape[1] #6

encoding_dim = 4
input_dim = Input(shape = (ncol, ))
# Encoder Layers
encoded1 = Dense(5, activation = 'relu')(input_dim)
encoded2 = Dense(encoding_dim, activation = 'relu')(encoded1)
# Decoder Layers
decoded1 = Dense(5, activation = 'relu')(encoded2)
decoded2 = Dense(ncol, activation = 'sigmoid')(decoded1)
# Combine Encoder and Deocder layers
autoencoder = Model(inputs = input_dim, outputs = decoded2)
autoencoder.compile(optimizer = 'adam', loss = 'mse')

autoencoder.fit(norm_reshaped_input, norm_reshaped_input, epochs = 500, batch_size = 32, shuffle = False)
encoder = Model(inputs = input_dim, outputs = encoded2)
encoded_input = Input(shape = (encoding_dim, ))
auto_out = np.array(encoder.predict(norm_reshaped_input))

new_theta_input=auto_out.reshape(auto_out.shape[0],auto_out.shape[1],1)
autoencoder.save('MyModelCheckpoint/autoencoder_model.h5')
encoder.save('MyModelCheckpoint/encoder_model.h5')
np.savetxt('MyModelCheckpoint/new_theta_input.csv',auto_out, fmt='%1.3f',delimiter=',')

# %% [markdown]
# ### Horizon =12        (12--->4)

# %%
theta_length = predictions.shape[0]

horizon=12
window_size=6
theta_all=np.zeros(0)
for i in range(theta_length):
    current_pred= np.asarray(predictions.iloc[i].dropna().values,dtype=float)
    theta_all=np.concatenate((theta_all,current_pred),axis=0)
theta_input = make_k_input(theta_all,window_size,horizon)
normalized_theta_input=np.zeros(theta_input.shape)
for j in range(theta_input.shape[0]):
    scaler = MinMaxScaler()
    scaler.fit(theta_input[j])
    normalized_theta_input[j]= scaler.transform(theta_input[j])
#######################################################################################
norm_reshaped_input=normalized_theta_input.reshape(normalized_theta_input.shape[0],12)
ncol = normalized_theta_input.shape[1] #12

encoding_dim = 4
input_dim = Input(shape = (ncol, ))
# Encoder Layers
encoded1 = Dense(9, activation = 'relu')(input_dim)
encoded2 = Dense(6, activation = 'relu')(encoded1)
encoded3 = Dense(encoding_dim, activation = 'relu')(encoded2)
# Decoder Layers
decoded1 = Dense(6, activation = 'relu')(encoded3)
decoded2 = Dense(9, activation = 'relu')(decoded1)
decoded3 = Dense(ncol, activation = 'sigmoid')(decoded2)
# Combine Encoder and Deocder layers
autoencoder = Model(inputs = input_dim, outputs = decoded3)
autoencoder.compile(optimizer = 'adam', loss = 'mse')

autoencoder.fit(norm_reshaped_input, norm_reshaped_input, epochs = 500, batch_size = 32, shuffle = False)
encoder = Model(inputs = input_dim, outputs = encoded3)
encoded_input = Input(shape = (encoding_dim, ))
auto_out = np.array(encoder.predict(norm_reshaped_input))

new_theta_input=auto_out.reshape(auto_out.shape[0],auto_out.shape[1],1)
autoencoder.save('MyModelCheckpoint/autoencoder_model_h12_to_4.h5')
encoder.save('MyModelCheckpoint/encoder_model_h12_to_4.h5')
np.savetxt('MyModelCheckpoint/new_theta_input_h12_to_4.csv',auto_out, fmt='%1.3f',delimiter=',')

# %% [markdown]
# ### Horizon =12        (12--->6)

# %%
theta_length = predictions.shape[0]

horizon=12
window_size=6
theta_all=np.zeros(0)
for i in range(theta_length):
    current_pred= np.asarray(predictions.iloc[i].dropna().values,dtype=float)
    theta_all=np.concatenate((theta_all,current_pred),axis=0)
theta_input = make_k_input(theta_all,window_size,horizon)
normalized_theta_input=np.zeros(theta_input.shape)
for j in range(theta_input.shape[0]):
    scaler = MinMaxScaler()
    scaler.fit(theta_input[j])
    normalized_theta_input[j]= scaler.transform(theta_input[j])
#######################################################################################
norm_reshaped_input=normalized_theta_input.reshape(normalized_theta_input.shape[0],12)
ncol = normalized_theta_input.shape[1] #12

encoding_dim = 6
input_dim = Input(shape = (ncol, ))
# Encoder Layers
encoded1 = Dense(10, activation = 'relu')(input_dim)
encoded2 = Dense(8, activation = 'relu')(encoded1)
encoded3 = Dense(encoding_dim, activation = 'relu')(encoded2)
# Decoder Layers
decoded1 = Dense(8, activation = 'relu')(encoded3)
decoded2 = Dense(10, activation = 'relu')(decoded1)
decoded3 = Dense(ncol, activation = 'sigmoid')(decoded2)
# Combine Encoder and Deocder layers
autoencoder = Model(inputs = input_dim, outputs = decoded3)
autoencoder.compile(optimizer = 'adam', loss = 'mse')

autoencoder.fit(norm_reshaped_input, norm_reshaped_input, epochs = 500, batch_size = 32, shuffle = False)
encoder = Model(inputs = input_dim, outputs = encoded3)
encoded_input = Input(shape = (encoding_dim, ))
auto_out = np.array(encoder.predict(norm_reshaped_input))

new_theta_input=auto_out.reshape(auto_out.shape[0],auto_out.shape[1],1)
autoencoder.save('MyModelCheckpoint/autoencoder_model_h12_to_6.h5')
encoder.save('MyModelCheckpoint/encoder_model_h12_to_6.h5')
np.savetxt('MyModelCheckpoint/new_theta_input_h12_to_6.csv',auto_out, fmt='%1.3f',delimiter=',')

# %% [markdown]
# ### Horizon =12        (12--->8)

# %%
theta_length = predictions.shape[0]

horizon=12
window_size=6
theta_all=np.zeros(0)
for i in range(theta_length):
    current_pred= np.asarray(predictions.iloc[i].dropna().values,dtype=float)
    theta_all=np.concatenate((theta_all,current_pred),axis=0)
theta_input = make_k_input(theta_all,window_size,horizon)
normalized_theta_input=np.zeros(theta_input.shape)
for j in range(theta_input.shape[0]):
    scaler = MinMaxScaler()
    scaler.fit(theta_input[j])
    normalized_theta_input[j]= scaler.transform(theta_input[j])
#######################################################################################
norm_reshaped_input=normalized_theta_input.reshape(normalized_theta_input.shape[0],12)
ncol = normalized_theta_input.shape[1] #12

encoding_dim = 8
input_dim = Input(shape = (ncol, ))
# Encoder Layers
encoded1 = Dense(10, activation = 'relu')(input_dim)
encoded2 = Dense(9, activation = 'relu')(encoded1)
encoded3 = Dense(encoding_dim, activation = 'relu')(encoded2)
# Decoder Layers
decoded1 = Dense(9, activation = 'relu')(encoded3)
decoded2 = Dense(10, activation = 'relu')(decoded1)
decoded3 = Dense(ncol, activation = 'sigmoid')(decoded2)
# Combine Encoder and Deocder layers
autoencoder = Model(inputs = input_dim, outputs = decoded3)
autoencoder.compile(optimizer = 'adam', loss = 'mse')

autoencoder.fit(norm_reshaped_input, norm_reshaped_input, epochs = 500, batch_size = 32, shuffle = False)
encoder = Model(inputs = input_dim, outputs = encoded3)
encoded_input = Input(shape = (encoding_dim, ))
auto_out = np.array(encoder.predict(norm_reshaped_input))

new_theta_input=auto_out.reshape(auto_out.shape[0],auto_out.shape[1],1)
autoencoder.save('MyModelCheckpoint/autoencoder_model_h12_to_8.h5')
encoder.save('MyModelCheckpoint/encoder_model_h12_to_8.h5')
np.savetxt('MyModelCheckpoint/new_theta_input_h12_to_8.csv',auto_out, fmt='%1.3f',delimiter=',')

# %% [markdown]
# # Case 6: Only Data
# #### Horizon = 6 or 12
# #### Window size = 6

# %%
print(datetime.datetime.now())
smape1=0
smape2=0
mse1=0
data_length = data.shape[0]
with tqdm(total=data_length) as pbar:
    final_predictions = np.zeros([data_length,12])
    final_test = np.zeros([data_length,12])
    Final_smape1=np.zeros(data_length)
    for y in range(data_length):
        
        
        
        num_test = data.iloc[y].values[1]
        horizon=data.iloc[y].values[1]
        window_size=6
        current_row =np.asarray(data.loc[y][3:].dropna().values,dtype=float)
        rr = current_row.size
        rr = int(np.floor(rr*.25))
        series_d=current_row[rr:] # values after (rr)th position in current_row
#####################################################################
        series_data = series_d[:-num_test]
        series_length = series_data.size
        n_val = int(np.round(series_length*.2))
        
        if n_val < horizon: #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            n_val = horizon#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            
            
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################
        LL=series_data.shape[0]-n_val
        HH=LL-window_size+1-horizon
        if (HH<0):
            train = series_data[:-n_val+1-HH]
        else:
            train = series_data[:-n_val]                        
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################

        #train = series_data[:-n_val+3]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
        test = series_d[-(num_test+window_size):]
        val = series_data[-(n_val+window_size):]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

        train_sequence = make_input(train, window_size,horizon)
        val_sequence = make_input(val,window_size,horizon)
        test_sequence = nonov_make_input(test,window_size,horizon)

        train_sequence_norm = deepcopy(train_sequence)
        val_sequence_norm = deepcopy(val_sequence)
        test_sequence_norm = deepcopy(test_sequence)

        for j in range(train_sequence[0].shape[0]):
            scaler1 = MinMaxScaler()
            scaler1.fit(train_sequence[0][j])
            train_sequence_norm[0][j]= scaler1.transform(train_sequence[0][j])
            train_sequence_norm[1][j]= scaler1.transform(train_sequence[1][j].reshape(train_sequence[1][j].shape[0],1)).reshape(train_sequence[1][j].shape[0])
    

        for j in range(val_sequence[0].shape[0]):
            scaler2 = MinMaxScaler()
            scaler2.fit(val_sequence[0][j])
            val_sequence_norm[0][j]= scaler2.transform(val_sequence[0][j])
            val_sequence_norm[1][j]= scaler2.transform(val_sequence[1][j].reshape(val_sequence[1][j].shape[0],1)).reshape(val_sequence[1][j].shape[0])

        for j in range(test_sequence[0].shape[0]):
            scaler3 = MinMaxScaler()
            scaler3.fit(test_sequence[0][j])
            test_sequence_norm[0][j]= scaler3.transform(test_sequence[0][j])
            test_sequence_norm[1][j]= scaler3.transform(test_sequence[1][j].reshape(test_sequence[1][j].shape[0],1)).reshape(test_sequence[1][j].shape[0])
    
        current_test=series_d[-num_test:]


        x_train = train_sequence_norm[0]
        y_train =train_sequence_norm[1]
        x_val = val_sequence_norm[0]
        y_val = val_sequence_norm[1]
        
        x_test = test_sequence_norm[0]
        y_test = test_sequence_norm[1]
        
        #x_test = test_sequence_norm[0].reshape(1,test_sequence_norm[0].shape[0]*test_sequence_norm[0].shape[1],1)
        #y_test = test_sequence_norm[1].reshape(1,test_sequence_norm[1].shape[0]*test_sequence_norm[1].shape[1])
        
        
        
############################################################################################################
############################################################################################################
############################################################################################################
        train_input = x_train
        val_input = x_val
        test_input = x_test

####################################################################################
################       Neural Network Configuration         ########################
####################################################################################
        tf.reset_default_graph()
        K.clear_session()
        
        input_data= Input(batch_shape=(None,window_size,1),name='input_data')

        

        branch_0 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(input_data)
        branch_1 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_0)
        branch_2 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_1)
        branch_3=Flatten()(branch_2)
        net= Dense(horizon,name='dense_final',activity_regularizer=regularizers.l2(0.01))(branch_3)
        

        model=Model(inputs=[input_data],outputs=net)
        if y==71:
            model.summary()
        callback = ModelCheckpoint(filepath='MyModelCheckpoint/CIF01.h5',monitor='val_loss',save_best_only=True,save_weights_only=True)
        model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01))


        model.fit({'input_data':train_input},y_train,validation_data=[[val_input],y_val],callbacks=[callback],batch_size=8,shuffle=True, epochs=75,verbose=0)

        model.load_weights('MyModelCheckpoint/CIF01.h5')
        pred=model.predict({'input_data':test_input})
        pred=scaler3.inverse_transform(pred)#######################################################
        #pred.reshape(1,pred.shape[0]*pred.shape[1])

        final_predictions[y,:num_test] = pred.reshape(num_test)
        final_test[y,:num_test]=test[-num_test:]

        AAA=smape(pred.reshape(num_test),current_test,num_test)
        smape1+=AAA
        smape2+=smape_nzr(pred.reshape(num_test),current_test)
        Final_smape1[y]=AAA
        mse1+=mse(pred.reshape(num_test),current_test)
        pbar.update(1)

np.savetxt('MyModelCheckpoint/prediction01.csv',final_predictions, fmt='%1.3f',delimiter=',')
print(datetime.datetime.now())
print('-----------------')
print("SMAPE1: (DeepEX approach)")
print(smape1/72)
print("SMAPE2 (NZR approach)")
print(smape2/72)
print("MSE1:")
print(mse1/72)
print (sum(Final_smape1)/72)    
#print(smape1)
#print(smape2)
# Out:
# 2019-09-09 15:07:12.256236
#  99%|████████████████████████████████████████████████████████████████████████████████▊ | 71/72 [01:49<00:01,  1.31s/it]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_data (InputLayer)      (None, 6, 1)              0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 32)             128
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 6, 32)             3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 6, 32)             3104
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 192)               0
# _________________________________________________________________
# dense_final (Dense)          (None, 6)                 1158
# =================================================================
# Total params: 7,494
# Trainable params: 7,494
# Non-trainable params: 0
# _________________________________________________________________
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [01:51<00:00,  1.31s/it]
# 2019-09-09 15:09:03.260316
# -----------------
# SMAPE1: (DeepEX approach)
# 14.276737475218892
# SMAPE2 (NZR approach)
# 14.276737475218889
# MSE1:
# 5078877594190.866
# 14.276737475218892

# %% [markdown]
# # Case 7: Using 2 AutoEncoders
# ### Adding Expert Knowledge to layer 1
# ### 1st AutoEncoder : (6 to 4)
# ### 2nd AutoEncoder : (12 to 4)

# %%
print(datetime.datetime.now())
smape1=0
smape2=0
mse1=0
data_length = data.shape[0]
with tqdm(total=data_length) as pbar:
    final_predictions = np.zeros([data_length,12])
    final_test = np.zeros([data_length,12])
    Final_smape2=np.zeros(data_length)

    for y in range(data_length):
    #for y in range(1):
        
        
        num_test = data.iloc[y].values[1]
        #horizon=6
        horizon=data.iloc[y].values[1]
        window_size=6
        current_row =np.asarray(data.loc[y][3:].dropna().values,dtype=float)
        rr = current_row.size
        rr = int(np.floor(rr*.25))
        series_d=current_row[rr:] # values after (rr)th position in current_row
#####################################################################
        series_data = series_d[:-num_test]
        series_length = series_data.size
        n_val = int(np.round(series_length*.2))
        
        if n_val < horizon: #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            n_val = horizon#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            
            
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################
        LL=series_data.shape[0]-n_val
        HH=LL-window_size+1-horizon
        if (HH<0):
            train = series_data[:-n_val+1-HH]
        else:
            train = series_data[:-n_val]                        
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################

        #train = series_data[:-n_val+3]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
        test = series_d[-(num_test+window_size):]
        val = series_data[-(n_val+window_size):]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

        train_sequence = make_input(train, window_size,horizon)
        val_sequence = make_input(val,window_size,horizon)
        test_sequence = nonov_make_input(test,window_size,horizon)

        train_sequence_norm = deepcopy(train_sequence)
        val_sequence_norm = deepcopy(val_sequence)
        test_sequence_norm = deepcopy(test_sequence)

        for j in range(train_sequence[0].shape[0]):
            scaler1 = MinMaxScaler()
            scaler1.fit(train_sequence[0][j])
            train_sequence_norm[0][j]= scaler1.transform(train_sequence[0][j])
            train_sequence_norm[1][j]= scaler1.transform(train_sequence[1][j].reshape(train_sequence[1][j].shape[0],1)).reshape(train_sequence[1][j].shape[0])
    

        for j in range(val_sequence[0].shape[0]):
            scaler2 = MinMaxScaler()
            scaler2.fit(val_sequence[0][j])
            val_sequence_norm[0][j]= scaler2.transform(val_sequence[0][j])
            val_sequence_norm[1][j]= scaler2.transform(val_sequence[1][j].reshape(val_sequence[1][j].shape[0],1)).reshape(val_sequence[1][j].shape[0])

        for j in range(test_sequence[0].shape[0]):
            scaler3 = MinMaxScaler()
            scaler3.fit(test_sequence[0][j])
            test_sequence_norm[0][j]= scaler3.transform(test_sequence[0][j])
            test_sequence_norm[1][j]= scaler3.transform(test_sequence[1][j].reshape(test_sequence[1][j].shape[0],1)).reshape(test_sequence[1][j].shape[0])
    
        current_test=series_d[-num_test:]


        x_train = train_sequence_norm[0]
        y_train =train_sequence_norm[1]
        x_val = val_sequence_norm[0]
        y_val = val_sequence_norm[1]
        
        x_test = test_sequence_norm[0]
        y_test = test_sequence_norm[1]
        
############################################################################################################
############################################################################################################
############################################################################################################
        train_input = x_train
        val_input = x_val
        test_input = x_test

####################################################################################
#######creating train, validation and test sets from Predictions####################
####################################################################################
        current_pred= np.asarray(predictions.iloc[y].dropna().values,dtype=float)
#####################################################################
        series_p=current_pred
        series_pred=series_p[:-num_test]
        
        if (HH<0):
            train_p = series_pred[:-n_val+1-HH]
        else:
            train_p = series_pred[:-n_val]                        
        
        
        #train_p = series_pred[:-n_val+3]
        val_p = series_pred[-(n_val+window_size):]
        test_p = series_p[-(num_test+window_size):]

        train_pred = make_k_input(train_p,window_size,horizon)
        val_pred = make_k_input(val_p,window_size,horizon)
        test_pred = nonov_make_k_input(test_p,window_size,horizon)        
        
        
        train_pred_norm=np.zeros(train_pred.shape)
        val_pred_norm=np.zeros(val_pred.shape)
        test_pred_norm=np.zeros(test_pred.shape)
    
        for j in range(train_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(train_pred[j])
            train_pred_norm[j]= scaler.transform(train_pred[j])
        for j in range(val_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(val_pred[j])
            val_pred_norm[j]= scaler.transform(val_pred[j])
        for j in range(test_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(test_pred[j])
            test_pred_norm[j]= scaler.transform(test_pred[j])
        
        train_pred_norm=train_pred_norm.reshape(train_pred_norm.shape[0],train_pred_norm.shape[1])
        val_pred_norm=val_pred_norm.reshape(val_pred_norm.shape[0],val_pred_norm.shape[1])
        test_pred_norm=test_pred_norm.reshape(test_pred_norm.shape[0],test_pred_norm.shape[1])

##########################################################################################################################
        
        if (num_test==6):
            ncol = 6
            encoding_dim = 4
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
            
            
        elif (num_test==12):
            ncol = 12
            encoding_dim = 4
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model_h12_to_4.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
        else :
            print("ERRORRRRRRRRRRRRRRRRRRR")

                
        train_pred_norm_auto=pd.DataFrame(train_pred_norm_auto)
        val_pred_norm_auto=pd.DataFrame(val_pred_norm_auto)
        test_pred_auto=pd.DataFrame(test_pred_auto)                    
        
        

####################################################################################
################       Neural Network Configuration         ########################
####################################################################################
        tf.reset_default_graph()
        K.clear_session()
        
        input_data= Input(batch_shape=(None,window_size,1),name='input_data')
        input_pred=Input(batch_shape=(None,encoding_dim),name='input_pred')
        
        encoded12 = Dense(8, activation = 'relu')(input_pred)
        encoded22 = Dense(16, activation = 'relu')(encoded12)
        encoded32 = Dense(32, activation = 'relu')(encoded22)
        encoded32=Reshape((1,32))(encoded32)
        

        branch_0 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(input_data)
        branch_0=concatenate([branch_0,encoded32],axis=1)
        #branch_0=add([branch_0,encoded32])
        branch_1 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_0)
        #branch_1=add([branch_1,encoded32])
        branch_2 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_1)
        #branch_2=add([branch_2,encoded32])
        branch_3=Flatten()(branch_2)
        net= Dense(horizon,name='dense_final',activity_regularizer=regularizers.l2(0.01))(branch_3)
        

        model=Model(inputs=[input_data,input_pred],outputs=net)
        if y==71:
            model.summary()
        callback = ModelCheckpoint(filepath='MyModelCheckpoint/CIF05.h5',monitor='val_loss',save_best_only=True,save_weights_only=True)
        model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01))


        model.fit({'input_data':train_input,'input_pred':train_pred_norm_auto},y_train,validation_data=[[val_input,val_pred_norm_auto],y_val],callbacks=[callback],batch_size=8,shuffle=True, epochs=75,verbose=0)

        model.load_weights('MyModelCheckpoint/CIF05.h5')
        
        pred=model.predict({'input_data':test_input, 'input_pred':test_pred_auto})
        pred=scaler3.inverse_transform(pred)#######################################################

        
        final_predictions[y,:num_test] = pred.reshape(num_test)
        final_test[y,:num_test]=test[-num_test:]

        AAA=smape(pred.reshape(num_test),current_test,num_test)
        smape1+=AAA
        smape2+=smape_nzr(pred.reshape(num_test),current_test)
        Final_smape2[y]=AAA
        mse1+=mse(pred.reshape(num_test),current_test)
        pbar.update(1)

np.savetxt('MyModelCheckpoint/prediction05.csv',final_predictions, fmt='%1.3f',delimiter=',')
print(datetime.datetime.now())
print('-----------------')
print("SMAPE1: (DeepEX approach)")
print(smape1/72)
print("SMAPE2 (NZR approach)")
print(smape2/72)
print("MSE1:")
print(mse1/72)
print (sum(Final_smape2)/72)    
#print(smape1)
#print(smape2)
# Out:
# 2019-09-09 20:15:29.667569
#   0%|                                                                                           | 0/72 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   1%|█▏                                                                                 | 1/72 [00:02<03:23,  2.87s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   3%|██▎                                                                                | 2/72 [00:05<03:18,  2.83s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   4%|███▍                                                                               | 3/72 [00:08<03:16,  2.85s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   6%|████▌                                                                              | 4/72 [00:11<03:10,  2.80s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   7%|█████▊                                                                             | 5/72 [00:14<03:08,  2.81s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   8%|██████▉                                                                            | 6/72 [00:16<03:02,  2.77s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  10%|████████                                                                           | 7/72 [00:19<02:57,  2.72s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  11%|█████████▏                                                                         | 8/72 [00:22<02:57,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  12%|██████████▍                                                                        | 9/72 [00:24<02:51,  2.72s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  14%|███████████▍                                                                      | 10/72 [00:27<02:51,  2.76s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  15%|████████████▌                                                                     | 11/72 [00:30<02:46,  2.73s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  17%|█████████████▋                                                                    | 12/72 [00:33<02:46,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  18%|██████████████▊                                                                   | 13/72 [00:35<02:43,  2.77s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  19%|███████████████▉                                                                  | 14/72 [00:38<02:42,  2.81s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  21%|█████████████████                                                                 | 15/72 [00:41<02:39,  2.79s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  22%|██████████████████▏                                                               | 16/72 [00:44<02:40,  2.86s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  24%|███████████████████▎                                                              | 17/72 [00:47<02:37,  2.85s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  25%|████████████████████▌                                                             | 18/72 [00:50<02:34,  2.87s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  26%|█████████████████████▋                                                            | 19/72 [00:53<02:31,  2.85s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  28%|██████████████████████▊                                                           | 20/72 [00:56<02:30,  2.89s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  29%|███████████████████████▉                                                          | 21/72 [00:58<02:25,  2.85s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  31%|█████████████████████████                                                         | 22/72 [01:01<02:23,  2.88s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  32%|██████████████████████████▏                                                       | 23/72 [01:04<02:18,  2.83s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  33%|███████████████████████████▎                                                      | 24/72 [01:07<02:18,  2.89s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  35%|████████████████████████████▍                                                     | 25/72 [01:10<02:12,  2.82s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  36%|█████████████████████████████▌                                                    | 26/72 [01:13<02:10,  2.83s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  38%|██████████████████████████████▊                                                   | 27/72 [01:15<02:04,  2.77s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  39%|███████████████████████████████▉                                                  | 28/72 [01:18<02:02,  2.79s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  40%|█████████████████████████████████                                                 | 29/72 [01:21<01:57,  2.73s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  42%|██████████████████████████████████▏                                               | 30/72 [01:23<01:53,  2.71s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  43%|███████████████████████████████████▎                                              | 31/72 [01:26<01:53,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  44%|████████████████████████████████████▍                                             | 32/72 [01:29<01:49,  2.74s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  46%|█████████████████████████████████████▌                                            | 33/72 [01:32<01:48,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  47%|██████████████████████████████████████▋                                           | 34/72 [01:34<01:44,  2.75s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  49%|███████████████████████████████████████▊                                          | 35/72 [01:37<01:43,  2.80s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  50%|█████████████████████████████████████████                                         | 36/72 [01:40<01:39,  2.76s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  51%|██████████████████████████████████████████▏                                       | 37/72 [01:43<01:37,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  53%|███████████████████████████████████████████▎                                      | 38/72 [01:46<01:33,  2.76s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  54%|████████████████████████████████████████████▍                                     | 39/72 [01:48<01:31,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  56%|█████████████████████████████████████████████▌                                    | 40/72 [01:51<01:27,  2.74s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  57%|██████████████████████████████████████████████▋                                   | 41/72 [01:54<01:25,  2.76s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  58%|███████████████████████████████████████████████▊                                  | 42/72 [01:57<01:22,  2.77s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  60%|████████████████████████████████████████████████▉                                 | 43/72 [02:00<01:20,  2.78s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  61%|██████████████████████████████████████████████████                                | 44/72 [02:02<01:17,  2.76s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  62%|███████████████████████████████████████████████████▎                              | 45/72 [02:05<01:13,  2.73s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  64%|████████████████████████████████████████████████████▍                             | 46/72 [02:08<01:12,  2.77s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  65%|█████████████████████████████████████████████████████▌                            | 47/72 [02:10<01:08,  2.75s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  67%|██████████████████████████████████████████████████████▋                           | 48/72 [02:13<01:06,  2.79s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  68%|███████████████████████████████████████████████████████▊                          | 49/72 [02:15<00:58,  2.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  69%|████████████████████████████████████████████████████████▉                         | 50/72 [02:17<00:52,  2.38s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  71%|██████████████████████████████████████████████████████████                        | 51/72 [02:19<00:48,  2.30s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  72%|███████████████████████████████████████████████████████████▏                      | 52/72 [02:22<00:46,  2.30s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  74%|████████████████████████████████████████████████████████████▎                     | 53/72 [02:24<00:42,  2.23s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  75%|█████████████████████████████████████████████████████████████▌                    | 54/72 [02:26<00:41,  2.29s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  76%|██████████████████████████████████████████████████████████████▋                   | 55/72 [02:28<00:36,  2.17s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  78%|███████████████████████████████████████████████████████████████▊                  | 56/72 [02:30<00:35,  2.24s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  79%|████████████████████████████████████████████████████████████████▉                 | 57/72 [02:33<00:33,  2.20s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  81%|██████████████████████████████████████████████████████████████████                | 58/72 [02:35<00:30,  2.18s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  82%|███████████████████████████████████████████████████████████████████▏              | 59/72 [02:37<00:27,  2.14s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  83%|████████████████████████████████████████████████████████████████████▎             | 60/72 [02:39<00:26,  2.24s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  85%|█████████████████████████████████████████████████████████████████████▍            | 61/72 [02:41<00:24,  2.19s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  86%|██████████████████████████████████████████████████████████████████████▌           | 62/72 [02:44<00:22,  2.22s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  88%|███████████████████████████████████████████████████████████████████████▊          | 63/72 [02:46<00:19,  2.15s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  89%|████████████████████████████████████████████████████████████████████████▉         | 64/72 [02:48<00:17,  2.21s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  90%|██████████████████████████████████████████████████████████████████████████        | 65/72 [02:50<00:15,  2.26s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  92%|███████████████████████████████████████████████████████████████████████████▏      | 66/72 [02:53<00:13,  2.29s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  93%|████████████████████████████████████████████████████████████████████████████▎     | 67/72 [02:55<00:11,  2.22s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  94%|█████████████████████████████████████████████████████████████████████████████▍    | 68/72 [02:57<00:08,  2.19s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  96%|██████████████████████████████████████████████████████████████████████████████▌   | 69/72 [02:59<00:06,  2.24s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  97%|███████████████████████████████████████████████████████████████████████████████▋  | 70/72 [03:01<00:04,  2.19s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  99%|████████████████████████████████████████████████████████████████████████████████▊ | 71/72 [03:04<00:02,  2.23s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_pred (InputLayer)         (None, 4)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          input_pred[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           144         dense_1[0][0]
# __________________________________________________________________________________________________
# input_data (InputLayer)         (None, 6, 1)         0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           544         dense_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6, 32)        128         input_data[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 32)        0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 32)        0           conv1d_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 7, 64)        6208        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 64)        12352       conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 448)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# dense_final (Dense)             (None, 6)            2694        flatten_1[0][0]
# ==================================================================================================
# Total params: 22,110
# Trainable params: 22,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [03:06<00:00,  2.22s/it]
# 2019-09-09 20:18:36.026306
# -----------------
# SMAPE1: (DeepEX approach)
# 13.359560717727488
# SMAPE2 (NZR approach)
# 13.359560717727486
# MSE1:
# 3678264466871.486
# 13.359560717727488

# %% [markdown]
# # Case 8: Using 2 AutoEncoders
# ### Adding Expert Knowledge to layer 1
# ### 1st AutoEncoder : (6 to 4)
# ### 2nd AutoEncoder : (12 to 6)

# %%
print(datetime.datetime.now())
smape1=0
smape2=0
mse1=0
data_length = data.shape[0]
with tqdm(total=data_length) as pbar:
    final_predictions = np.zeros([data_length,12])
    final_test = np.zeros([data_length,12])
    Final_smape2=np.zeros(data_length)

    for y in range(data_length):
    #for y in range(1):
        
        
        num_test = data.iloc[y].values[1]
        #horizon=6
        horizon=data.iloc[y].values[1]
        window_size=6
        current_row =np.asarray(data.loc[y][3:].dropna().values,dtype=float)
        rr = current_row.size
        rr = int(np.floor(rr*.25))
        series_d=current_row[rr:] # values after (rr)th position in current_row
#####################################################################
        series_data = series_d[:-num_test]
        series_length = series_data.size
        n_val = int(np.round(series_length*.2))
        
        if n_val < horizon: #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            n_val = horizon#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            
            
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################
        LL=series_data.shape[0]-n_val
        HH=LL-window_size+1-horizon
        if (HH<0):
            train = series_data[:-n_val+1-HH]
        else:
            train = series_data[:-n_val]                        
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################

        #train = series_data[:-n_val+3]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
        test = series_d[-(num_test+window_size):]
        val = series_data[-(n_val+window_size):]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

        train_sequence = make_input(train, window_size,horizon)
        val_sequence = make_input(val,window_size,horizon)
        test_sequence = nonov_make_input(test,window_size,horizon)

        train_sequence_norm = deepcopy(train_sequence)
        val_sequence_norm = deepcopy(val_sequence)
        test_sequence_norm = deepcopy(test_sequence)

        for j in range(train_sequence[0].shape[0]):
            scaler1 = MinMaxScaler()
            scaler1.fit(train_sequence[0][j])
            train_sequence_norm[0][j]= scaler1.transform(train_sequence[0][j])
            train_sequence_norm[1][j]= scaler1.transform(train_sequence[1][j].reshape(train_sequence[1][j].shape[0],1)).reshape(train_sequence[1][j].shape[0])
    

        for j in range(val_sequence[0].shape[0]):
            scaler2 = MinMaxScaler()
            scaler2.fit(val_sequence[0][j])
            val_sequence_norm[0][j]= scaler2.transform(val_sequence[0][j])
            val_sequence_norm[1][j]= scaler2.transform(val_sequence[1][j].reshape(val_sequence[1][j].shape[0],1)).reshape(val_sequence[1][j].shape[0])

        for j in range(test_sequence[0].shape[0]):
            scaler3 = MinMaxScaler()
            scaler3.fit(test_sequence[0][j])
            test_sequence_norm[0][j]= scaler3.transform(test_sequence[0][j])
            test_sequence_norm[1][j]= scaler3.transform(test_sequence[1][j].reshape(test_sequence[1][j].shape[0],1)).reshape(test_sequence[1][j].shape[0])
    
        current_test=series_d[-num_test:]


        x_train = train_sequence_norm[0]
        y_train =train_sequence_norm[1]
        x_val = val_sequence_norm[0]
        y_val = val_sequence_norm[1]
        
        x_test = test_sequence_norm[0]
        y_test = test_sequence_norm[1]
        
############################################################################################################
############################################################################################################
############################################################################################################
        train_input = x_train
        val_input = x_val
        test_input = x_test

####################################################################################
#######creating train, validation and test sets from Predictions####################
####################################################################################
        current_pred= np.asarray(predictions.iloc[y].dropna().values,dtype=float)
#####################################################################
        series_p=current_pred
        series_pred=series_p[:-num_test]
        
        if (HH<0):
            train_p = series_pred[:-n_val+1-HH]
        else:
            train_p = series_pred[:-n_val]                        
        
        
        #train_p = series_pred[:-n_val+3]
        val_p = series_pred[-(n_val+window_size):]
        test_p = series_p[-(num_test+window_size):]

        train_pred = make_k_input(train_p,window_size,horizon)
        val_pred = make_k_input(val_p,window_size,horizon)
        test_pred = nonov_make_k_input(test_p,window_size,horizon)        
        
        
        train_pred_norm=np.zeros(train_pred.shape)
        val_pred_norm=np.zeros(val_pred.shape)
        test_pred_norm=np.zeros(test_pred.shape)
    
        for j in range(train_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(train_pred[j])
            train_pred_norm[j]= scaler.transform(train_pred[j])
        for j in range(val_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(val_pred[j])
            val_pred_norm[j]= scaler.transform(val_pred[j])
        for j in range(test_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(test_pred[j])
            test_pred_norm[j]= scaler.transform(test_pred[j])
        
        train_pred_norm=train_pred_norm.reshape(train_pred_norm.shape[0],train_pred_norm.shape[1])
        val_pred_norm=val_pred_norm.reshape(val_pred_norm.shape[0],val_pred_norm.shape[1])
        test_pred_norm=test_pred_norm.reshape(test_pred_norm.shape[0],test_pred_norm.shape[1])

##########################################################################################################################
        
        if (num_test==6):
            ncol = 6
            encoding_dim = 4
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
            
            
        elif (num_test==12):
            ncol = 12
            encoding_dim = 6
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model_h12_to_6.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
        else :
            print("ERRORRRRRRRRRRRRRRRRRRR")

                
        train_pred_norm_auto=pd.DataFrame(train_pred_norm_auto)
        val_pred_norm_auto=pd.DataFrame(val_pred_norm_auto)
        test_pred_auto=pd.DataFrame(test_pred_auto)                    
        
        

####################################################################################
################       Neural Network Configuration         ########################
####################################################################################
        tf.reset_default_graph()
        K.clear_session()
        
        input_data= Input(batch_shape=(None,window_size,1),name='input_data')
        input_pred=Input(batch_shape=(None,encoding_dim),name='input_pred')
        
        encoded12 = Dense(8, activation = 'relu')(input_pred)
        encoded22 = Dense(16, activation = 'relu')(encoded12)
        encoded32 = Dense(32, activation = 'relu')(encoded22)
        encoded32=Reshape((1,32))(encoded32)
        

        branch_0 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(input_data)
        branch_0=concatenate([branch_0,encoded32],axis=1)
        #branch_0=add([branch_0,encoded32])
        branch_1 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_0)
        #branch_1=add([branch_1,encoded32])
        branch_2 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_1)
        #branch_2=add([branch_2,encoded32])
        branch_3=Flatten()(branch_2)
        net= Dense(horizon,name='dense_final',activity_regularizer=regularizers.l2(0.01))(branch_3)
        

        model=Model(inputs=[input_data,input_pred],outputs=net)
        if y==71:
            model.summary()
        callback = ModelCheckpoint(filepath='MyModelCheckpoint/CIF07.h5',monitor='val_loss',save_best_only=True,save_weights_only=True)
        model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01))


        model.fit({'input_data':train_input,'input_pred':train_pred_norm_auto},y_train,validation_data=[[val_input,val_pred_norm_auto],y_val],callbacks=[callback],batch_size=8,shuffle=True, epochs=75,verbose=0)

        model.load_weights('MyModelCheckpoint/CIF07.h5')
        
        pred=model.predict({'input_data':test_input, 'input_pred':test_pred_auto})
        pred=scaler3.inverse_transform(pred)#######################################################

        
        final_predictions[y,:num_test] = pred.reshape(num_test)
        final_test[y,:num_test]=test[-num_test:]

        AAA=smape(pred.reshape(num_test),current_test,num_test)
        smape1+=AAA
        smape2+=smape_nzr(pred.reshape(num_test),current_test)
        Final_smape2[y]=AAA
        mse1+=mse(pred.reshape(num_test),current_test)
        pbar.update(1)

np.savetxt('MyModelCheckpoint/prediction07.csv',final_predictions, fmt='%1.3f',delimiter=',')
print(datetime.datetime.now())
print('-----------------')
print("SMAPE1: (DeepEX approach)")
print(smape1/72)
print("SMAPE2 (NZR approach)")
print(smape2/72)
print("MSE1:")
print(mse1/72)
print (sum(Final_smape2)/72)    
#print(smape1)
#print(smape2)
# Out:
# 2019-09-09 15:26:42.304727
#   0%|                                                                                           | 0/72 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   1%|█▏                                                                                 | 1/72 [00:02<03:01,  2.56s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   3%|██▎                                                                                | 2/72 [00:04<02:56,  2.52s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   4%|███▍                                                                               | 3/72 [00:07<02:57,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   6%|████▌                                                                              | 4/72 [00:10<02:53,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   7%|█████▊                                                                             | 5/72 [00:12<02:53,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   8%|██████▉                                                                            | 6/72 [00:15<02:47,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  10%|████████                                                                           | 7/72 [00:17<02:45,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  11%|█████████▏                                                                         | 8/72 [00:20<02:40,  2.51s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  12%|██████████▍                                                                        | 9/72 [00:22<02:36,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  14%|███████████▍                                                                      | 10/72 [00:25<02:36,  2.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  15%|████████████▌                                                                     | 11/72 [00:27<02:31,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  17%|█████████████▋                                                                    | 12/72 [00:30<02:32,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  18%|██████████████▊                                                                   | 13/72 [00:32<02:27,  2.51s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  19%|███████████████▉                                                                  | 14/72 [00:35<02:29,  2.57s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  21%|█████████████████                                                                 | 15/72 [00:37<02:24,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  22%|██████████████████▏                                                               | 16/72 [00:40<02:24,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  24%|███████████████████▎                                                              | 17/72 [00:43<02:20,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  25%|████████████████████▌                                                             | 18/72 [00:45<02:21,  2.61s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  26%|█████████████████████▋                                                            | 19/72 [00:48<02:17,  2.60s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  28%|██████████████████████▊                                                           | 20/72 [00:51<02:15,  2.60s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  29%|███████████████████████▉                                                          | 21/72 [00:53<02:10,  2.56s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  31%|█████████████████████████                                                         | 22/72 [00:56<02:09,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  32%|██████████████████████████▏                                                       | 23/72 [00:58<02:05,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  33%|███████████████████████████▎                                                      | 24/72 [01:01<02:02,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  35%|████████████████████████████▍                                                     | 25/72 [01:03<02:01,  2.60s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  36%|█████████████████████████████▌                                                    | 26/72 [01:06<01:58,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  38%|██████████████████████████████▊                                                   | 27/72 [01:09<01:56,  2.59s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  39%|███████████████████████████████▉                                                  | 28/72 [01:11<01:51,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  40%|█████████████████████████████████                                                 | 29/72 [01:14<01:51,  2.59s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  42%|██████████████████████████████████▏                                               | 30/72 [01:16<01:46,  2.52s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  43%|███████████████████████████████████▎                                              | 31/72 [01:19<01:43,  2.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  44%|████████████████████████████████████▍                                             | 32/72 [01:21<01:39,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  46%|█████████████████████████████████████▌                                            | 33/72 [01:23<01:37,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  47%|██████████████████████████████████████▋                                           | 34/72 [01:26<01:33,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  49%|███████████████████████████████████████▊                                          | 35/72 [01:28<01:31,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  50%|█████████████████████████████████████████                                         | 36/72 [01:31<01:28,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  51%|██████████████████████████████████████████▏                                       | 37/72 [01:33<01:26,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  53%|███████████████████████████████████████████▎                                      | 38/72 [01:36<01:23,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  54%|████████████████████████████████████████████▍                                     | 39/72 [01:38<01:20,  2.43s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  56%|█████████████████████████████████████████████▌                                    | 40/72 [01:41<01:18,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  57%|██████████████████████████████████████████████▋                                   | 41/72 [01:43<01:16,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  58%|███████████████████████████████████████████████▊                                  | 42/72 [01:46<01:15,  2.51s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  60%|████████████████████████████████████████████████▉                                 | 43/72 [01:48<01:12,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  61%|██████████████████████████████████████████████████                                | 44/72 [01:51<01:10,  2.51s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  62%|███████████████████████████████████████████████████▎                              | 45/72 [01:53<01:06,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  64%|████████████████████████████████████████████████████▍                             | 46/72 [01:56<01:04,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  65%|█████████████████████████████████████████████████████▌                            | 47/72 [01:58<01:01,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  67%|██████████████████████████████████████████████████████▋                           | 48/72 [02:01<00:59,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  68%|███████████████████████████████████████████████████████▊                          | 49/72 [02:02<00:51,  2.25s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  69%|████████████████████████████████████████████████████████▉                         | 50/72 [02:04<00:46,  2.12s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  71%|██████████████████████████████████████████████████████████                        | 51/72 [02:06<00:43,  2.06s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  72%|███████████████████████████████████████████████████████████▏                      | 52/72 [02:08<00:40,  2.04s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  74%|████████████████████████████████████████████████████████████▎                     | 53/72 [02:10<00:37,  2.00s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  75%|█████████████████████████████████████████████████████████████▌                    | 54/72 [02:12<00:36,  2.04s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  76%|██████████████████████████████████████████████████████████████▋                   | 55/72 [02:14<00:33,  1.96s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  78%|███████████████████████████████████████████████████████████████▊                  | 56/72 [02:16<00:32,  2.00s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  79%|████████████████████████████████████████████████████████████████▉                 | 57/72 [02:18<00:29,  1.96s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  81%|██████████████████████████████████████████████████████████████████                | 58/72 [02:20<00:26,  1.89s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  82%|███████████████████████████████████████████████████████████████████▏              | 59/72 [02:21<00:24,  1.92s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  83%|████████████████████████████████████████████████████████████████████▎             | 60/72 [02:24<00:23,  1.96s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  85%|█████████████████████████████████████████████████████████████████████▍            | 61/72 [02:26<00:21,  1.99s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  86%|██████████████████████████████████████████████████████████████████████▌           | 62/72 [02:28<00:19,  1.97s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  88%|███████████████████████████████████████████████████████████████████████▊          | 63/72 [02:29<00:17,  1.95s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  89%|████████████████████████████████████████████████████████████████████████▉         | 64/72 [02:31<00:15,  1.93s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  90%|██████████████████████████████████████████████████████████████████████████        | 65/72 [02:34<00:14,  2.03s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  92%|███████████████████████████████████████████████████████████████████████████▏      | 66/72 [02:36<00:12,  2.00s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  93%|████████████████████████████████████████████████████████████████████████████▎     | 67/72 [02:37<00:09,  1.97s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  94%|█████████████████████████████████████████████████████████████████████████████▍    | 68/72 [02:39<00:07,  1.91s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  96%|██████████████████████████████████████████████████████████████████████████████▌   | 69/72 [02:41<00:06,  2.02s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  97%|███████████████████████████████████████████████████████████████████████████████▋  | 70/72 [02:43<00:03,  1.97s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  99%|████████████████████████████████████████████████████████████████████████████████▊ | 71/72 [02:45<00:01,  1.99s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_pred (InputLayer)         (None, 4)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          input_pred[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           144         dense_1[0][0]
# __________________________________________________________________________________________________
# input_data (InputLayer)         (None, 6, 1)         0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           544         dense_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6, 32)        128         input_data[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 32)        0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 32)        0           conv1d_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 7, 64)        6208        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 64)        12352       conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 448)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# dense_final (Dense)             (None, 6)            2694        flatten_1[0][0]
# ==================================================================================================
# Total params: 22,110
# Trainable params: 22,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [02:47<00:00,  1.97s/it]
# 2019-09-09 15:29:30.085908
# -----------------
# SMAPE1: (DeepEX approach)
# 13.775521262030914
# SMAPE2 (NZR approach)
# 13.775521262030914
# MSE1:
# 5383340815616.324
# 13.775521262030914

# %% [markdown]
# # Case 9: Using 2 AutoEncoders
# ### Adding Expert Knowledge to layer 1
# ### 1st AutoEncoder : (6 to 4)
# ### 2nd AutoEncoder : (12 to 8)

# %%
print(datetime.datetime.now())
smape1=0
smape2=0
mse1=0
data_length = data.shape[0]
with tqdm(total=data_length) as pbar:
    final_predictions = np.zeros([data_length,12])
    final_test = np.zeros([data_length,12])
    Final_smape2=np.zeros(data_length)

    for y in range(data_length):
    #for y in range(1):
        
        
        num_test = data.iloc[y].values[1]
        #horizon=6
        horizon=data.iloc[y].values[1]
        window_size=6
        current_row =np.asarray(data.loc[y][3:].dropna().values,dtype=float)
        rr = current_row.size
        rr = int(np.floor(rr*.25))
        series_d=current_row[rr:] # values after (rr)th position in current_row
#####################################################################
        series_data = series_d[:-num_test]
        series_length = series_data.size
        n_val = int(np.round(series_length*.2))
        
        if n_val < horizon: #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            n_val = horizon#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            
            
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################
        LL=series_data.shape[0]-n_val
        HH=LL-window_size+1-horizon
        if (HH<0):
            train = series_data[:-n_val+1-HH]
        else:
            train = series_data[:-n_val]                        
        ##########################$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##########################

        #train = series_data[:-n_val+3]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
        test = series_d[-(num_test+window_size):]
        val = series_data[-(n_val+window_size):]#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

        train_sequence = make_input(train, window_size,horizon)
        val_sequence = make_input(val,window_size,horizon)
        test_sequence = nonov_make_input(test,window_size,horizon)

        train_sequence_norm = deepcopy(train_sequence)
        val_sequence_norm = deepcopy(val_sequence)
        test_sequence_norm = deepcopy(test_sequence)

        for j in range(train_sequence[0].shape[0]):
            scaler1 = MinMaxScaler()
            scaler1.fit(train_sequence[0][j])
            train_sequence_norm[0][j]= scaler1.transform(train_sequence[0][j])
            train_sequence_norm[1][j]= scaler1.transform(train_sequence[1][j].reshape(train_sequence[1][j].shape[0],1)).reshape(train_sequence[1][j].shape[0])
    

        for j in range(val_sequence[0].shape[0]):
            scaler2 = MinMaxScaler()
            scaler2.fit(val_sequence[0][j])
            val_sequence_norm[0][j]= scaler2.transform(val_sequence[0][j])
            val_sequence_norm[1][j]= scaler2.transform(val_sequence[1][j].reshape(val_sequence[1][j].shape[0],1)).reshape(val_sequence[1][j].shape[0])

        for j in range(test_sequence[0].shape[0]):
            scaler3 = MinMaxScaler()
            scaler3.fit(test_sequence[0][j])
            test_sequence_norm[0][j]= scaler3.transform(test_sequence[0][j])
            test_sequence_norm[1][j]= scaler3.transform(test_sequence[1][j].reshape(test_sequence[1][j].shape[0],1)).reshape(test_sequence[1][j].shape[0])
    
        current_test=series_d[-num_test:]


        x_train = train_sequence_norm[0]
        y_train =train_sequence_norm[1]
        x_val = val_sequence_norm[0]
        y_val = val_sequence_norm[1]
        
        x_test = test_sequence_norm[0]
        y_test = test_sequence_norm[1]
        
############################################################################################################
############################################################################################################
############################################################################################################
        train_input = x_train
        val_input = x_val
        test_input = x_test

####################################################################################
#######creating train, validation and test sets from Predictions####################
####################################################################################
        current_pred= np.asarray(predictions.iloc[y].dropna().values,dtype=float)
#####################################################################
        series_p=current_pred
        series_pred=series_p[:-num_test]
        
        if (HH<0):
            train_p = series_pred[:-n_val+1-HH]
        else:
            train_p = series_pred[:-n_val]                        
        
        
        #train_p = series_pred[:-n_val+3]
        val_p = series_pred[-(n_val+window_size):]
        test_p = series_p[-(num_test+window_size):]

        train_pred = make_k_input(train_p,window_size,horizon)
        val_pred = make_k_input(val_p,window_size,horizon)
        test_pred = nonov_make_k_input(test_p,window_size,horizon)        
        
        
        train_pred_norm=np.zeros(train_pred.shape)
        val_pred_norm=np.zeros(val_pred.shape)
        test_pred_norm=np.zeros(test_pred.shape)
    
        for j in range(train_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(train_pred[j])
            train_pred_norm[j]= scaler.transform(train_pred[j])
        for j in range(val_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(val_pred[j])
            val_pred_norm[j]= scaler.transform(val_pred[j])
        for j in range(test_pred.shape[0]):
            scaler = MinMaxScaler()
            scaler.fit(test_pred[j])
            test_pred_norm[j]= scaler.transform(test_pred[j])
        
        train_pred_norm=train_pred_norm.reshape(train_pred_norm.shape[0],train_pred_norm.shape[1])
        val_pred_norm=val_pred_norm.reshape(val_pred_norm.shape[0],val_pred_norm.shape[1])
        test_pred_norm=test_pred_norm.reshape(test_pred_norm.shape[0],test_pred_norm.shape[1])

##########################################################################################################################
        
        if (num_test==6):
            ncol = 6
            encoding_dim = 4
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
            
            
        elif (num_test==12):
            ncol = 12
            encoding_dim = 8
            input_dim = Input(shape = (ncol, ))

            input_dim = Input(shape = (ncol, ))
            encoded_input = Input(shape = (encoding_dim, ))
            encoder=load_model('MyModelCheckpoint/encoder_model_h12_to_8.h5')
            train_pred_norm_auto=np.array(encoder.predict(train_pred_norm))
            val_pred_norm_auto=np.array(encoder.predict(val_pred_norm))
            test_pred_auto=np.array(encoder.predict(test_pred_norm))
        else :
            print("ERRORRRRRRRRRRRRRRRRRRR")

                
        train_pred_norm_auto=pd.DataFrame(train_pred_norm_auto)
        val_pred_norm_auto=pd.DataFrame(val_pred_norm_auto)
        test_pred_auto=pd.DataFrame(test_pred_auto)                    
        
        

####################################################################################
################       Neural Network Configuration         ########################
####################################################################################
        tf.reset_default_graph()
        K.clear_session()
        
        input_data= Input(batch_shape=(None,window_size,1),name='input_data')
        input_pred=Input(batch_shape=(None,encoding_dim),name='input_pred')
        
        encoded12 = Dense(8, activation = 'relu')(input_pred)
        encoded22 = Dense(16, activation = 'relu')(encoded12)
        encoded32 = Dense(32, activation = 'relu')(encoded22)
        encoded32=Reshape((1,32))(encoded32)
        

        branch_0 = Conv1D(32,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(input_data)
        branch_0=concatenate([branch_0,encoded32],axis=1)
        #branch_0=add([branch_0,encoded32])
        branch_1 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_0)
        #branch_1=add([branch_1,encoded32])
        branch_2 = Conv1D(64,3, strides=1, padding='same',activation='relu',kernel_initializer=glorot_uniform(1))(branch_1)
        #branch_2=add([branch_2,encoded32])
        branch_3=Flatten()(branch_2)
        net= Dense(horizon,name='dense_final',activity_regularizer=regularizers.l2(0.01))(branch_3)
        

        model=Model(inputs=[input_data,input_pred],outputs=net)
        if y==71:
            model.summary()
        callback = ModelCheckpoint(filepath='MyModelCheckpoint/CIF08.h5',monitor='val_loss',save_best_only=True,save_weights_only=True)
        model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01))


        model.fit({'input_data':train_input,'input_pred':train_pred_norm_auto},y_train,validation_data=[[val_input,val_pred_norm_auto],y_val],callbacks=[callback],batch_size=8,shuffle=True, epochs=75,verbose=0)

        model.load_weights('MyModelCheckpoint/CIF08.h5')
        
        pred=model.predict({'input_data':test_input, 'input_pred':test_pred_auto})
        pred=scaler3.inverse_transform(pred)#######################################################

        
        final_predictions[y,:num_test] = pred.reshape(num_test)
        final_test[y,:num_test]=test[-num_test:]

        AAA=smape(pred.reshape(num_test),current_test,num_test)
        smape1+=AAA
        smape2+=smape_nzr(pred.reshape(num_test),current_test)
        Final_smape2[y]=AAA
        mse1+=mse(pred.reshape(num_test),current_test)
        pbar.update(1)

np.savetxt('MyModelCheckpoint/prediction08.csv',final_predictions, fmt='%1.3f',delimiter=',')
print(datetime.datetime.now())
print('-----------------')
print("SMAPE1: (DeepEX approach)")
print(smape1/72)
print("SMAPE2 (NZR approach)")
print(smape2/72)
print("MSE1:")
print(mse1/72)
print (sum(Final_smape2)/72)    
#print(smape1)
#print(smape2)
# Out:
# 2019-09-09 15:29:32.007651
#   0%|                                                                                           | 0/72 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   1%|█▏                                                                                 | 1/72 [00:02<03:03,  2.58s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   3%|██▎                                                                                | 2/72 [00:04<02:57,  2.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   4%|███▍                                                                               | 3/72 [00:07<02:54,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   6%|████▌                                                                              | 4/72 [00:09<02:49,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   7%|█████▊                                                                             | 5/72 [00:12<02:47,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   8%|██████▉                                                                            | 6/72 [00:14<02:42,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  10%|████████                                                                           | 7/72 [00:17<02:37,  2.42s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  11%|█████████▏                                                                         | 8/72 [00:19<02:37,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  12%|██████████▍                                                                        | 9/72 [00:22<02:32,  2.43s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  14%|███████████▍                                                                      | 10/72 [00:24<02:35,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  15%|████████████▌                                                                     | 11/72 [00:27<02:30,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  17%|█████████████▋                                                                    | 12/72 [00:29<02:29,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  18%|██████████████▊                                                                   | 13/72 [00:32<02:24,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  19%|███████████████▉                                                                  | 14/72 [00:34<02:24,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  21%|█████████████████                                                                 | 15/72 [00:37<02:22,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  22%|██████████████████▏                                                               | 16/72 [00:39<02:21,  2.52s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  24%|███████████████████▎                                                              | 17/72 [00:42<02:17,  2.51s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  25%|████████████████████▌                                                             | 18/72 [00:44<02:17,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  26%|█████████████████████▋                                                            | 19/72 [00:47<02:15,  2.55s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  28%|██████████████████████▊                                                           | 20/72 [00:49<02:11,  2.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  29%|███████████████████████▉                                                          | 21/72 [00:52<02:10,  2.57s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  31%|█████████████████████████                                                         | 22/72 [00:55<02:07,  2.54s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  32%|██████████████████████████▏                                                       | 23/72 [00:57<02:06,  2.57s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  33%|███████████████████████████▎                                                      | 24/72 [01:00<02:03,  2.57s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  35%|████████████████████████████▍                                                     | 25/72 [01:02<02:00,  2.56s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  36%|█████████████████████████████▌                                                    | 26/72 [01:05<01:54,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  38%|██████████████████████████████▊                                                   | 27/72 [01:07<01:52,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  39%|███████████████████████████████▉                                                  | 28/72 [01:09<01:48,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  40%|█████████████████████████████████                                                 | 29/72 [01:12<01:46,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  42%|██████████████████████████████████▏                                               | 30/72 [01:14<01:43,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  43%|███████████████████████████████████▎                                              | 31/72 [01:17<01:41,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  44%|████████████████████████████████████▍                                             | 32/72 [01:19<01:37,  2.44s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  46%|█████████████████████████████████████▌                                            | 33/72 [01:22<01:34,  2.42s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  47%|██████████████████████████████████████▋                                           | 34/72 [01:24<01:33,  2.47s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  49%|███████████████████████████████████████▊                                          | 35/72 [01:27<01:30,  2.44s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  50%|█████████████████████████████████████████                                         | 36/72 [01:29<01:28,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  51%|██████████████████████████████████████████▏                                       | 37/72 [01:32<01:26,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  53%|███████████████████████████████████████████▎                                      | 38/72 [01:34<01:25,  2.52s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  54%|████████████████████████████████████████████▍                                     | 39/72 [01:37<01:21,  2.47s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  56%|█████████████████████████████████████████████▌                                    | 40/72 [01:39<01:19,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  57%|██████████████████████████████████████████████▋                                   | 41/72 [01:42<01:16,  2.46s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  58%|███████████████████████████████████████████████▊                                  | 42/72 [01:44<01:15,  2.52s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  60%|████████████████████████████████████████████████▉                                 | 43/72 [01:47<01:11,  2.48s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  61%|██████████████████████████████████████████████████                                | 44/72 [01:49<01:10,  2.50s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  62%|███████████████████████████████████████████████████▎                              | 45/72 [01:51<01:06,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  64%|████████████████████████████████████████████████████▍                             | 46/72 [01:54<01:04,  2.47s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  65%|█████████████████████████████████████████████████████▌                            | 47/72 [01:56<01:01,  2.45s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  67%|██████████████████████████████████████████████████████▋                           | 48/72 [01:59<00:59,  2.49s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  68%|███████████████████████████████████████████████████████▊                          | 49/72 [02:01<00:51,  2.25s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  69%|████████████████████████████████████████████████████████▉                         | 50/72 [02:02<00:45,  2.08s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  71%|██████████████████████████████████████████████████████████                        | 51/72 [02:04<00:43,  2.06s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  72%|███████████████████████████████████████████████████████████▏                      | 52/72 [02:06<00:39,  2.00s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  74%|████████████████████████████████████████████████████████████▎                     | 53/72 [02:08<00:38,  2.01s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  75%|█████████████████████████████████████████████████████████████▌                    | 54/72 [02:10<00:36,  2.00s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  76%|██████████████████████████████████████████████████████████████▋                   | 55/72 [02:12<00:33,  1.94s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  78%|███████████████████████████████████████████████████████████████▊                  | 56/72 [02:14<00:31,  1.95s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  79%|████████████████████████████████████████████████████████████████▉                 | 57/72 [02:16<00:29,  1.99s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  81%|██████████████████████████████████████████████████████████████████                | 58/72 [02:18<00:27,  1.94s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  82%|███████████████████████████████████████████████████████████████████▏              | 59/72 [02:20<00:24,  1.92s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  83%|████████████████████████████████████████████████████████████████████▎             | 60/72 [02:22<00:23,  1.98s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  85%|█████████████████████████████████████████████████████████████████████▍            | 61/72 [02:24<00:21,  1.95s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  86%|██████████████████████████████████████████████████████████████████████▌           | 62/72 [02:26<00:19,  1.97s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  88%|███████████████████████████████████████████████████████████████████████▊          | 63/72 [02:28<00:17,  1.90s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  89%|████████████████████████████████████████████████████████████████████████▉         | 64/72 [02:30<00:15,  1.98s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  90%|██████████████████████████████████████████████████████████████████████████        | 65/72 [02:32<00:14,  2.03s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  92%|███████████████████████████████████████████████████████████████████████████▏      | 66/72 [02:34<00:12,  2.03s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  93%|████████████████████████████████████████████████████████████████████████████▎     | 67/72 [02:36<00:09,  1.93s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  94%|█████████████████████████████████████████████████████████████████████████████▍    | 68/72 [02:37<00:07,  1.91s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  96%|██████████████████████████████████████████████████████████████████████████████▌   | 69/72 [02:40<00:05,  1.99s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  97%|███████████████████████████████████████████████████████████████████████████████▋  | 70/72 [02:42<00:03,  1.99s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#  99%|████████████████████████████████████████████████████████████████████████████████▊ | 71/72 [02:43<00:01,  1.96s/it]C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_pred (InputLayer)         (None, 4)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          input_pred[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           144         dense_1[0][0]
# __________________________________________________________________________________________________
# input_data (InputLayer)         (None, 6, 1)         0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           544         dense_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6, 32)        128         input_data[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 32)        0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 32)        0           conv1d_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 7, 64)        6208        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 64)        12352       conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 448)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# dense_final (Dense)             (None, 6)            2694        flatten_1[0][0]
# ==================================================================================================
# Total params: 22,110
# Trainable params: 22,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [02:46<00:00,  2.03s/it]
# 2019-09-09 15:32:18.199820
# -----------------
# SMAPE1: (DeepEX approach)
# 13.927934920202716
# SMAPE2 (NZR approach)
# 13.927934920202715
# MSE1:
# 4983881963957.285
# 13.927934920202716
